# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
with pd.HDFStore('/Users/lukemcdermott/Desktop/Physics/spectral_templates_data_version_june20.h5') as hdf:
    # This prints a list of all group names:
    print(hdf.keys())

bin_df = pd.read_hdf('/Users/lukemcdermott/Desktop/Physics/spectral_templates_data_version_june20.h5', key = '/binaries')
sin_df = pd.read_hdf('/Users/lukemcdermott/Desktop/Physics/spectral_templates_data_version_june20.h5', key = '/singles')
wav_df = pd.read_hdf('/Users/lukemcdermott/Desktop/Physics/spectral_templates_data_version_june20.h5', key = '/wavegrid')
# Out:
# ['/binaries', '/singles', '/wavegrid']

# %%
display(bin_df)
display(sin_df)
# Out:
#           flux_0    flux_1    flux_2    flux_3    flux_4    flux_5    flux_6  \
# 0       0.568345  0.615487  0.668477  0.705189  0.698754  0.700950  0.717146
# 1       0.496365  0.563067  0.602393  0.659527  0.682808  0.676481  0.674343
# 2       0.520227  0.580531  0.627045  0.645281  0.665795  0.678923  0.686509
# 3       0.483774  0.556865  0.603915  0.641451  0.698212  0.728678  0.666010
# 4       0.434787  0.504214  0.543165  0.611378  0.659270  0.680497  0.663214
# ...          ...       ...       ...       ...       ...       ...       ...
# 110809  0.030098  0.014580 -0.007441 -0.006942 -0.007369  0.006425  0.016458
# 110810  0.005596  0.004737 -0.002069  0.010406  0.006171  0.009747  0.011305
# 110848  0.073538  0.009197 -0.005860 -0.038976 -0.014792 -0.014072  0.036644
# 110849  0.001377 -0.014757 -0.004499  0.012407 -0.003643 -0.001074  0.012893
# 110887  0.054611  0.005404 -0.005459 -0.029133 -0.010909 -0.011670  0.031216
#
# ...

# %%
#all data together, 436 singles, rest binaries
df = bin_df.iloc[:,:441].append(sin_df.iloc[:,:441], ignore_index=True)
display(df)
# Out:
#          flux_0    flux_1    flux_2    flux_3    flux_4    flux_5    flux_6  \
# 0      0.568345  0.615487  0.668477  0.705189  0.698754  0.700950  0.717146
# 1      0.496365  0.563067  0.602393  0.659527  0.682808  0.676481  0.674343
# 2      0.520227  0.580531  0.627045  0.645281  0.665795  0.678923  0.686509
# 3      0.483774  0.556865  0.603915  0.641451  0.698212  0.728678  0.666010
# 4      0.434787  0.504214  0.543165  0.611378  0.659270  0.680497  0.663214
# ...         ...       ...       ...       ...       ...       ...       ...
# 42439 -0.004027 -0.007743 -0.004455  0.005451  0.001937 -0.002612  0.002762
# 42440  0.008489  0.009103 -0.001436  0.010861  0.008182  0.012516  0.011853
# 42441 -0.004778  0.078588  0.011728 -0.005535  0.033752  0.007601 -0.034531
# 42442  0.073008  0.009225 -0.005804 -0.039170 -0.014236 -0.015112  0.038132
# 42443  0.001837 -0.014860 -0.004494  0.012385 -0.003599 -0.001110  0.012853
#
# ...

# %%
#oversample
over_df = bin_df.iloc[:,:441]
over_classes = bin_df.iloc[:,-1]
print(over_df.shape)
for _ in range (90):
    over_df = over_df.append(sin_df.iloc[:,:441])
    over_classes = over_classes.append(sin_df.iloc[:,-2])
# Out:
# (42008, 441)

# %%
def eigsort(V, eigvals):
    # Sort the eigenvalues from largest to smallest. Store the sorted
    # eigenvalues in the column vector lambd.
    lohival = np.sort(eigvals)
    lohiindex = np.argsort(eigvals)
    lambd = np.flip(lohival)
    index = np.flip(lohiindex)
    Dsort = np.diag(lambd)
    
    # Sort eigenvectors to correspond to the ordered eigenvalues. Store sorted
    # eigenvectors as columns of the matrix vsort.
    M = np.size(lambd)
    Vsort = np.zeros((M, M))
    for i in range(M):
        Vsort[:,i] = V[:,index[i]]
    return Vsort, Dsort

def PCA(x):
  n = x.shape[0]

  mean = np.mean(x, axis = 0, keepdims = True)  #Avg Pattern
  x = x - mean  #Zero mean the data

  cov = (x.T @ x) / n 
  e_values, e_vectors = np.linalg.eig(cov)  
  sort_vec, sort_val = eigsort(e_vectors, e_values) #sort vectors based on biggest eigenvalues

  #debugging, delete next two lines later
  print(sort_val.diagonal()[:10])

  plt.plot(range(len(sort_val)), sort_val.diagonal()) #Print Scree Plot
  plt.show()

  PCA_coords = x @ sort_vec[:,:2] #Apply transformaton

  print('DIMENSIONS:')
  print('Cov shape:',cov.shape)
  print('E_val shape:',e_values.shape)
  print('E values:', sort_val)
  print('E_vec shape:',e_vectors.shape)
  print('sort_val shape:',sort_val.shape)
  print('sort_vec shape:',sort_vec.shape)
  print('mean shape:',mean.shape)
  print('x shape:',x.shape)
  print('PCA shape:', PCA_coords.shape)
  return PCA_coords

# %%
sin_x = sin_df.iloc[:,:441].to_numpy()
print(np.shape(sin_x))
sin_p = PCA(sin_x)
# Out:
# (436, 441)
# /var/folders/5w/ycx3z0zs70x9_kjtgxw3k7j00000gn/T/ipykernel_12849/755037981.py:15: ComplexWarning: Casting complex values to real discards the imaginary part
#   Vsort[:,i] = V[:,index[i]]
# [1.39637662e+01+0.j 3.20967330e+00+0.j 7.62172831e-01+0.j
#  1.84296748e-01+0.j 1.40235158e-01+0.j 5.06823714e-02+0.j
#  4.29775045e-02+0.j 1.55048867e-02+0.j 1.40477794e-02+0.j
#  1.06109663e-02+0.j]
# /opt/homebrew/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# DIMENSIONS:
# Cov shape: (441, 441)
# E_val shape: (441,)
# E values: [[ 1.39637662e+01+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  3.20967330e+00+0.00000000e+00j
# ...

# %%
bin_x = bin_df.iloc[:,:441].to_numpy()
print(np.shape(bin_x))
bin_p = PCA(bin_x)
# Out:
# (42008, 441)
# [10.23824798  4.25223712  0.73238703  0.22077987  0.17983317  0.12642293
#   0.07839464  0.06643093  0.03832948  0.02665545]
# DIMENSIONS:
# Cov shape: (441, 441)
# E_val shape: (441,)
# E values: [[1.02382480e+01 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 4.25223712e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 7.32387031e-01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.96073298e-07
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   2.84879424e-07 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 2.58577144e-07]]
# E_vec shape: (441, 441)
# sort_val shape: (441, 441)
# sort_vec shape: (441, 441)
# mean shape: (1, 441)
# x shape: (42008, 441)
# PCA shape: (42008, 2)

# %%
print(over_df.shape)
over_df_p = PCA(over_df.to_numpy())
# Out:
# (81248, 441)
# [12.24475409  3.83343767  0.74846328  0.2036158   0.15882696  0.08294776
#   0.05930035  0.04516999  0.0300849   0.02277653]
# DIMENSIONS:
# Cov shape: (441, 441)
# E_val shape: (441,)
# E values: [[1.22447541e+01 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.83343767e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 7.48463282e-01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.55425316e-07
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   2.39926993e-07 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 2.14223973e-07]]
# E_vec shape: (441, 441)
# sort_val shape: (441, 441)
# sort_vec shape: (441, 441)
# mean shape: (1, 441)
# x shape: (81248, 441)
# PCA shape: (81248, 2)

# %% [markdown]
# Separating by Binary / Single

# %%
for i in range(len(over_df_p) // 10):
    if i*10 < 436 * 90:
        #binary
        plt.scatter(over_df_p[i*10][0], over_df_p[i*10][1], color = 'black')
    else:
        #single
        plt.scatter(over_df_p[i*10][0], over_df_p[i*10][1], color = 'red')

# %%
over_classes = over_classes.to_numpy()

# %%
np.shape(over_classes)
print(over_classes[0])
# Out:
# 16.0

# %% [markdown]
# Separating by Spectral Class

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, 40))
for i in range(len(over_df_p) // 10):
    plt.scatter(over_df_p[i*5][0], over_df_p[i*5][1], color = colors[int(over_classes[i*5])])

# %% [markdown]
# Spectral Classes of PCA'ed Singles

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, 40))
for i in range():
    plt.scatter(sin_p[i][0], sin_p[i][1], color = colors[int(sin_df.to_numpy()[i,-2])])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5w/ycx3z0zs70x9_kjtgxw3k7j00000gn/T/ipykernel_12849/357905741.py in <module>
#       1 colors = plt.cm.rainbow(np.linspace(0, 1, 40))
# ----> 2 for i in range():
#       3     plt.scatter(sin_p[i][0], sin_p[i][1], color = colors[int(sin_df.to_numpy()[i,-2])])
#
# TypeError: range expected at least 1 argument, got 0
